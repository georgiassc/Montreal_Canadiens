# %%
import pandas as pd

# %%
nhl = pd.read_csv ('/content/drive/MyDrive/nhlplayoffs.csv')

# %%
nhl
# Out:
#       rank                  team  year  games  wins  losses  ties  \
# 0        1    Colorado Avalanche  2022     20    16       4     0
# 1        2   Tampa Bay Lightning  2022     23    14       9     0
# 2        3      New York Rangers  2022     20    10      10     0
# 3        4       Edmonton Oilers  2022     16     8       8     0
# 4        5   Carolina Hurricanes  2022     14     7       7     0
# ...    ...                   ...   ...    ...   ...     ...   ...
# 1004     2  Toronto St. Patricks  1921      2     0       2     0
# 1005     1    Montreal Canadiens  1919      5     4       1     0
# 1006     2       Ottawa Senators  1919      5     1       4     0
# 1007     1    Montreal Canadiens  1918      2     1       1     0
# 1008     2        Toronto Arenas  1918      2     1       1     0
#
#       shootout_wins  shootout_losses  win_loss_percentage  goals_scored  \
# 0                 5                1                0.800            85
# 1                 1                2                0.609            67
# 2                 1                2                0.500            62
# 3                 1                2                0.500            65
# 4                 1                0                0.500            37
# ...             ...              ...                  ...           ...
# 1004              0                0                0.000             0
# 1005              0                0                0.800            26
# 1006              0                0                0.200            18
# 1007              0                0                0.500             7
# 1008              0                0                0.500            10
#
#       goals_against  goal_differential
# 0                55                 30
# 1                61                  6
# 2                58                  4
# 3                59                  6
# 4                40                 -3
# ...             ...                ...
# 1004              7                 -7
# 1005             18                  8
# 1006             26                 -8
# 1007             10                 -3
# 1008              7                  3
#
# [1009 rows x 13 columns]

# %% [markdown]
# 1. What years did the Montreal Canadiens win the Stanley Cup?

# %%
print('Montreal Canadiens Championship Wins:', len(nhl[nhl['team'].str.contains('Montreal Canadiens') & (nhl['rank'] == 1)]))
montreal = nhl[nhl['team'].str.contains('Montreal Canadiens') & (nhl['rank'] == 1)]
montreal.sort_values('year')
# Out:
# Montreal Canadiens Championship Wins: 27
#       rank                team  year  games  wins  losses  ties  \
# 1007     1  Montreal Canadiens  1918      2     1       1     0
# 1005     1  Montreal Canadiens  1919      5     4       1     0
# 999      1  Montreal Canadiens  1923      2     1       1     0
# 997      1  Montreal Canadiens  1924      2     2       0     0
# 995      1  Montreal Canadiens  1925      2     2       0     0
# 968      1  Montreal Canadiens  1930      6     5       0     1
# 962      1  Montreal Canadiens  1931     10     6       4     0
# 888      1  Montreal Canadiens  1944      9     8       1     0
# 880      1  Montreal Canadiens  1946      9     8       1     0
# 852      1  Montreal Canadiens  1953     12     8       4     0
# 840      1  Montreal Canadiens  1956     10     8       2     0
# 836      1  Montreal Canadiens  1957     10     8       2     0
# 832      1  Montreal Canadiens  1958     10     8       2     0
# 828      1  Montreal Canadiens  1959     11     8       3     0
# 824      1  Montreal Canadiens  1960      8     8       0     0
# 804      1  Montreal Canadiens  1965     13     8       5     0
# 800      1  Montreal Canadiens  1966     10     8       2     0
# 788      1  Montreal Canadiens  1968     13    12       1     0
# 780      1  Montreal Canadiens  1969     14    12       2     0
# 764      1  Montreal Canadiens  1971     20    12       8     0
# 748      1  Montreal Canadiens  1973     17    12       5     0
# 716      1  Montreal Canadiens  1976     13    12       1     0
# 704      1  Montreal Canadiens  1978     14    12       2     0
# 692      1  Montreal Canadiens  1978     15    12       3     0
# 680      1  Montreal Canadiens  1979     16    12       4     0
# 568      1  Montreal Canadiens  1986     20    15       5     0
# 456      1  Montreal Canadiens  1993     20    16       4     0
#
#       shootout_wins  shootout_losses  win_loss_percentage  goals_scored  \
# 1007              0                0                0.500             7
# 1005              0                0                0.800            26
# 999               0                0                0.500             2
# 997               0                0                1.000             5
# 995               0                0                1.000             5
# 968               1                0                0.917            14
# 962               2                3                0.600            24
# 888               1                0                0.889            39
# 880               2                1                0.889            45
# 852               1                1                0.667            34
# 840               0                0                0.800            42
# 836               1                1                0.800            37
# 832               2                0                0.800            35
# 828               0                1                0.727            39
# 824               1                0                1.000            29
# 804               1                1                0.615            35
# 800               1                0                0.800            33
# 788               3                0                0.923            48
# 780               3                0                0.857            43
# 764               0                1                0.600            75
# 748               1                2                0.706            73
# 716               0                0                0.923            44
# 704               1                1                0.857            54
# 692               1                1                0.800            58
# 680               4                1                0.750            63
# 568               3                1                0.750            56
# 456              10                1                0.800            66
#
#       goals_against  goal_differential
# 1007             10                 -3
# 1005             18                  8
# 999               3                 -1
# 997               2                  3
# 995               2                  3
# 968               6                  8
# 962              21                  3
# 888              14                 25
# 880              20                 25
# 852              23                 11
# 840              18                 24
# 836              18                 19
# 832              20                 15
# 828              28                 11
# 824              11                 18
# 804              26                  9
# 800              20                 13
# 788              25                 23
# 780              26                 17
# 764              63                 12
# 748              52                 21
# 716              26                 18
# 704              23                 31
# 692              29                 29
# 680              41                 22
# 568              41                 15
# 456              51                 15

# %%
montrealW.drop([1007, 1005, 999, 995], inplace=True)
montrealW.sort_values('year')
# Out:
# <ipython-input-77-0d75c8431989>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   montrealW.drop([1007, 1005, 999, 995], inplace=True)
#      rank                team  year  games  wins  losses  ties  shootout_wins  \
# 997     1  Montreal Canadiens  1924      2     2       0     0              0
# 968     1  Montreal Canadiens  1930      6     5       0     1              1
# 962     1  Montreal Canadiens  1931     10     6       4     0              2
# 888     1  Montreal Canadiens  1944      9     8       1     0              1
# 880     1  Montreal Canadiens  1946      9     8       1     0              2
# 852     1  Montreal Canadiens  1953     12     8       4     0              1
# 840     1  Montreal Canadiens  1956     10     8       2     0              0
# 836     1  Montreal Canadiens  1957     10     8       2     0              1
# 832     1  Montreal Canadiens  1958     10     8       2     0              2
# 828     1  Montreal Canadiens  1959     11     8       3     0              0
# 824     1  Montreal Canadiens  1960      8     8       0     0              1
# 804     1  Montreal Canadiens  1965     13     8       5     0              1
# 800     1  Montreal Canadiens  1966     10     8       2     0              1
# 788     1  Montreal Canadiens  1968     13    12       1     0              3
# 780     1  Montreal Canadiens  1969     14    12       2     0              3
# 764     1  Montreal Canadiens  1971     20    12       8     0              0
# 748     1  Montreal Canadiens  1973     17    12       5     0              1
# 716     1  Montreal Canadiens  1976     13    12       1     0              0
# 704     1  Montreal Canadiens  1978     14    12       2     0              1
# 692     1  Montreal Canadiens  1978     15    12       3     0              1
# 680     1  Montreal Canadiens  1979     16    12       4     0              4
# 568     1  Montreal Canadiens  1986     20    15       5     0              3
# 456     1  Montreal Canadiens  1993     20    16       4     0             10
#
#      shootout_losses  win_loss_percentage  goals_scored  goals_against  \
# 997                0                1.000             5              2
# 968                0                0.917            14              6
# 962                3                0.600            24             21
# 888                0                0.889            39             14
# 880                1                0.889            45             20
# 852                1                0.667            34             23
# 840                0                0.800            42             18
# 836                1                0.800            37             18
# 832                0                0.800            35             20
# 828                1                0.727            39             28
# 824                0                1.000            29             11
# 804                1                0.615            35             26
# 800                0                0.800            33             20
# 788                0                0.923            48             25
# 780                0                0.857            43             26
# 764                1                0.600            75             63
# 748                2                0.706            73             52
# 716                0                0.923            44             26
# 704                1                0.857            54             23
# 692                1                0.800            58             29
# 680                1                0.750            63             41
# 568                1                0.750            56             41
# 456                1                0.800            66             51
#
#      goal_differential
# 997                  3
# 968                  8
# 962                  3
# 888                 25
# 880                 25
# 852                 11
# 840                 24
# 836                 19
# 832                 15
# 828                 11
# 824                 18
# 804                  9
# 800                 13
# 788                 23
# 780                 17
# 764                 12
# 748                 21
# 716                 18
# 704                 31
# 692                 29
# 680                 22
# 568                 15
# 456                 15

# %%
montrealW.loc[704, 'year'] = 1977
montrealW.sort_values('year')
# Out:
#      rank                team  year  games  wins  losses  ties  shootout_wins  \
# 997     1  Montreal Canadiens  1924      2     2       0     0              0
# 968     1  Montreal Canadiens  1930      6     5       0     1              1
# 962     1  Montreal Canadiens  1931     10     6       4     0              2
# 888     1  Montreal Canadiens  1944      9     8       1     0              1
# 880     1  Montreal Canadiens  1946      9     8       1     0              2
# 852     1  Montreal Canadiens  1953     12     8       4     0              1
# 840     1  Montreal Canadiens  1956     10     8       2     0              0
# 836     1  Montreal Canadiens  1957     10     8       2     0              1
# 832     1  Montreal Canadiens  1958     10     8       2     0              2
# 828     1  Montreal Canadiens  1959     11     8       3     0              0
# 824     1  Montreal Canadiens  1960      8     8       0     0              1
# 804     1  Montreal Canadiens  1965     13     8       5     0              1
# 800     1  Montreal Canadiens  1966     10     8       2     0              1
# 788     1  Montreal Canadiens  1968     13    12       1     0              3
# 780     1  Montreal Canadiens  1969     14    12       2     0              3
# 764     1  Montreal Canadiens  1971     20    12       8     0              0
# 748     1  Montreal Canadiens  1973     17    12       5     0              1
# 716     1  Montreal Canadiens  1976     13    12       1     0              0
# 704     1  Montreal Canadiens  1977     14    12       2     0              1
# 692     1  Montreal Canadiens  1978     15    12       3     0              1
# 680     1  Montreal Canadiens  1979     16    12       4     0              4
# 568     1  Montreal Canadiens  1986     20    15       5     0              3
# 456     1  Montreal Canadiens  1993     20    16       4     0             10
#
#      shootout_losses  win_loss_percentage  goals_scored  goals_against  \
# 997                0                1.000             5              2
# 968                0                0.917            14              6
# 962                3                0.600            24             21
# 888                0                0.889            39             14
# 880                1                0.889            45             20
# 852                1                0.667            34             23
# 840                0                0.800            42             18
# 836                1                0.800            37             18
# 832                0                0.800            35             20
# 828                1                0.727            39             28
# 824                0                1.000            29             11
# 804                1                0.615            35             26
# 800                0                0.800            33             20
# 788                0                0.923            48             25
# 780                0                0.857            43             26
# 764                1                0.600            75             63
# 748                2                0.706            73             52
# 716                0                0.923            44             26
# 704                1                0.857            54             23
# 692                1                0.800            58             29
# 680                1                0.750            63             41
# 568                1                0.750            56             41
# 456                1                0.800            66             51
#
#      goal_differential
# 997                  3
# 968                  8
# 962                  3
# 888                 25
# 880                 25
# 852                 11
# 840                 24
# 836                 19
# 832                 15
# 828                 11
# 824                 18
# 804                  9
# 800                 13
# 788                 23
# 780                 17
# 764                 12
# 748                 21
# 716                 18
# 704                 31
# 692                 29
# 680                 22
# 568                 15
# 456                 15

# %%
value = montrealW['rank'].value_counts ()
value
# Out:
# rank
# 1    23
# Name: count, dtype: int64

# %%
montreal_years_wins = montrealW[['year']]
montreal_years_wins
# Out:
#      year
# 456  1993
# 568  1986
# 680  1979
# 692  1978
# 704  1977
# 716  1976
# 748  1973
# 764  1971
# 780  1969
# 788  1968
# 800  1966
# 804  1965
# 824  1960
# 828  1959
# 832  1958
# 836  1957
# 840  1956
# 852  1953
# 880  1946
# 888  1944
# 962  1931
# 968  1930
# 997  1924

# %% [markdown]
# 2. How did the Montreal Canadiens perform overall in the playoffs over the years?

# %%
montreal_perform = nhl[nhl['team'].str.contains('Montreal Canadiens')]
montrealper = montreal_perform.loc [:, ['year', 'rank']]
montrealper
# Out:
#       year  rank
# 17    2021     2
# 39    2020     8
# 97    2017    10
# 125   2015     6
# 139   2014     4
# ...    ...   ...
# 995   1925     1
# 997   1924     1
# 999   1923     1
# 1005  1919     1
# 1007  1918     1
#
# [85 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# montrealper['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# montrealper['rank'].plot(kind='hist', bins=20, title='rank')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# montrealper.plot(kind='scatter', x='year', y='rank', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['year']
#   ys = series['rank']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = montrealper.sort_values('year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('rank')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'year'}, axis=1)
#               .sort_values('year', ascending=True))
#   xs = counted['year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = montrealper.sort_values('year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('year')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# montrealper['year'].plot(kind='line', figsize=(8, 4), title='year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# montrealper['rank'].plot(kind='line', figsize=(8, 4), title='rank')
# plt.gca().spines[['top', 'right']].set_visible(False)
